# %% [markdown]
# # 🚀 Streamlit Dashboard Demo (Notebook Preview)
#
# This notebook acts as a **design prototype** for the interactive Streamlit dashboard that enables exploration of **relativistic time dilation models** across three domains:
#
# - 🔁 Time Dilation due to Speed (Special Relativity)
# - 🌌 Gravitational Time Dilation (General Relativity)
# - ☄️ Particle Decay & Relativistic Travel
#
# While Streamlit runs as a web app, this notebook helps test:
# - 📈 Plot behavior
# - 🎛️ Widget-controlled filters
# - 🧠 Output logic for explanations
#
# ➡️ The deployable version lives in: `app/streamlit_dashboard.py`

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import warnings

warnings.filterwarnings("ignore")
sns.set(style="whitegrid")
plt.rcParams['figure.figsize'] = (10, 6)

# %%
df_speed = pd.read_csv("../data/raw/time_dilation_high_speed_particles.csv")
df_gravity = pd.read_csv("../data/raw/gravitational_time_dilation.csv")
df_decay = pd.read_csv("../data/raw/particle_decay_time_dilation.csv")

# %% [markdown]
# ## 🔁 Special Relativity – Speed-Based Time Dilation
#
# This plot shows how **time appears to dilate** (slow down) as an object's velocity approaches the **speed of light**.
#
# We use the Lorentz factor (γ) to calculate the observed time from Earth’s frame.

# %%
plt.figure()
sns.lineplot(
    data=df_speed,
    x='Velocity Fraction of c',
    y='Dilated Time (s)',
    label='Dilated Time (Earth Observer)',
    color='blue'
)
plt.axhline(1.0, color='gray', linestyle='--', label='Proper Time (1s)')
plt.title("Time Dilation vs Velocity (Special Relativity)", fontsize=14)
plt.xlabel("Velocity (fraction of speed of light, c)")
plt.ylabel("Dilated Time (seconds)")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🌌 Gravitational Time Dilation
#
# This plot simulates how time is dilated **near a black hole**, where the intense gravity curves spacetime. The closer the observer to the event horizon (1 Rₛ), the slower time moves relative to a distant observer.

# %%
plt.figure()
sns.lineplot(
    data=df_gravity,
    x='Distance in Rs',
    y='Dilated Time (s)',
    label='Dilated Time (Distant Observer)',
    color='darkorange'
)
plt.axhline(1.0, color='gray', linestyle='--', label='Proper Time (1s)')
plt.title("Gravitational Time Dilation vs Distance from Black Hole", fontsize=14)
plt.xlabel("Distance from Center (in Schwarzschild radii, Rₛ)")
plt.ylabel("Dilated Time (seconds)")
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🎛️ Scenario Selection (for Streamlit)
#
# In the deployed app, the user can choose:
# - One of the three models (speed, gravity, decay)
# - Adjust proper time or input velocity
# - See dynamic results
#
# This logic will be part of the Streamlit UI, not run here in Jupyter.

# %%
# Pseudo-code for streamlit implementation
scenario = "Speed-based"  # example selection

if scenario == "Speed-based":
    display(df_speed.head(3))
elif scenario == "Gravity-based":
    display(df_gravity.head(3))
elif scenario == "Decay":
    display(df_decay.head(3))
# Out:
#    Velocity Fraction of c  Velocity (m/s)  Lorentz Factor (γ)  \
# 0                0.100000    2.997925e+07            1.005038
# 1                0.118163    3.542446e+07            1.007055
# 2                0.136327    4.086967e+07            1.009424
#
#    Proper Time (s)  Dilated Time (s)
# 0              1.0          1.005038
# 1              1.0          1.007055
# 2              1.0          1.009424

# %% [markdown]
# ## ✅ Summary
#
# This notebook previews what will become an **interactive data storytelling dashboard** via Streamlit.
#
# Each model includes:
# - 📈 Graphs
# - 📊 Table views
# - 🧪 User inputs for deeper exploration
#
# ---
#
# ### ▶️ To Launch the Full App:
# ```bash
# cd app/
# streamlit run streamlit_dashboard.py
